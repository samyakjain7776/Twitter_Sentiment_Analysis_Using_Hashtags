# %%
# !pip install textblob
# !pip install tweepy
import sys,tweepy,csv,re
from textblob import TextBlob
import matplotlib.pyplot as plt

class SentimentAnalysis:

    def __init__(self):
        self.tweets = []
        self.tweetText = []

    def DownloadData(self):
        # authenticating
        consumerKey =''
        consumerSecret =''
        accessToken = ''
        accessTokenSecret = ''
        auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
        auth.set_access_token(accessToken, accessTokenSecret)
        api = tweepy.API(auth)

        
        searchTerm = input("Enter Keyword/Tag to search about: ")
        NoOfTerms = int(input("Enter how many tweets to search: "))

        # searching for tweets
        self.tweets = tweepy.Cursor(api.search, q=searchTerm, lang = "en").items(NoOfTerms)

        # Open/create a file to append data to
        csvFile = open('result.csv', 'a')

        csvWriter = csv.writer(csvFile)

        polarity = 0
        positive = 0
        wpositive = 0
        spositive = 0
        negative = 0
        wnegative = 0
        snegative = 0
        neutral = 0


        
        for tweet in self.tweets:
            print(tweet.text)
            self.tweetText.append(self.cleanTweet(tweet.text).encode('utf-8'))
            
            analysis = TextBlob(tweet.text)
           
            polarity += analysis.sentiment.polarity  
            if (analysis.sentiment.polarity == 0): 
                neutral += 1
            elif (analysis.sentiment.polarity > 0 and analysis.sentiment.polarity <= 0.3):
                wpositive += 1
            elif (analysis.sentiment.polarity > 0.3 and analysis.sentiment.polarity <= 0.6):
                positive += 1
            elif (analysis.sentiment.polarity > 0.6 and analysis.sentiment.polarity <= 1):
                spositive += 1
            elif (analysis.sentiment.polarity > -0.3 and analysis.sentiment.polarity <= 0):
                wnegative += 1
            elif (analysis.sentiment.polarity > -0.6 and analysis.sentiment.polarity <= -0.3):
                negative += 1
            elif (analysis.sentiment.polarity > -1 and analysis.sentiment.polarity <= -0.6):
                snegative += 1


        
        csvWriter.writerow(self.tweetText)
        csvFile.close()

        # finding average of how people are reacting
        positive = self.percentage(positive, NoOfTerms)
        wpositive = self.percentage(wpositive, NoOfTerms)
        spositive = self.percentage(spositive, NoOfTerms)
        negative = self.percentage(negative, NoOfTerms)
        wnegative = self.percentage(wnegative, NoOfTerms)
        snegative = self.percentage(snegative, NoOfTerms)
        neutral = self.percentage(neutral, NoOfTerms)

        # finding average reaction
        polarity = polarity / NoOfTerms

        
        print("How people are reacting on " + searchTerm + " by analyzing " + str(NoOfTerms) + " tweets.")
        print()
        print("General Report: ")

        if (polarity == 0):
            print("Neutral")
        elif (polarity > 0 and polarity <= 0.3):
            print("Weakly Positive")
        elif (polarity > 0.3 and polarity <= 0.6):
            print("Positive")
        elif (polarity > 0.6 and polarity <= 1):
            print("Strongly Positive")
        elif (polarity > -0.3 and polarity <= 0):
            print("Weakly Negative")
        elif (polarity > -0.6 and polarity <= -0.3):
            print("Negative")
        elif (polarity > -1 and polarity <= -0.6):
            print("Strongly Negative")

        print()
        print("Detailed Report: ")
        print(str(positive) + "% people thought it was positive")
        print(str(wpositive) + "% people thought it was weakly positive")
        print(str(spositive) + "% people thought it was strongly positive")
        print(str(negative) + "% people thought it was negative")
        print(str(wnegative) + "% people thought it was weakly negative")
        print(str(snegative) + "% people thought it was strongly negative")
        print(str(neutral) + "% people thought it was neutral")

        self.plotPieChart(positive, wpositive, spositive, negative, wnegative, snegative, neutral, searchTerm, NoOfTerms)


    def cleanTweet(self, tweet):
        # Remove Links, Special Characters etc from tweet
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) | (\w +:\ / \ / \S +)", " ", tweet).split())

    # function to calculate percentage
    def percentage(self, part, whole):
        temp = 100 * float(part) / float(whole)
        return format(temp, '.2f')

    def plotPieChart(self, positive, wpositive, spositive, negative, wnegative, snegative, neutral, searchTerm, noOfSearchTerms):
        labels = ['Positive [' + str(positive) + '%]', 'Weakly Positive [' + str(wpositive) + '%]','Strongly Positive [' + str(spositive) + '%]', 'Neutral [' + str(neutral) + '%]',
                  'Negative [' + str(negative) + '%]', 'Weakly Negative [' + str(wnegative) + '%]', 'Strongly Negative [' + str(snegative) + '%]']
        sizes = [positive, wpositive, spositive, neutral, negative, wnegative, snegative]
        colors = ['yellowgreen','lightgreen','darkgreen', 'gold', 'red','lightsalmon','darkred']
        patches, texts = plt.pie(sizes, colors=colors, startangle=90)
        plt.legend(patches, labels, loc="best")
        plt.title('How people are reacting on ' + searchTerm + ' by analyzing ' + str(noOfSearchTerms) + ' Tweets.')
        plt.axis('equal')
        plt.tight_layout()
        plt.show()

if __name__== "__main__":
    sa = SentimentAnalysis()
    sa.DownloadData()
# Out:
# Requirement already satisfied: textblob in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.15.3)
# Requirement already satisfied: nltk>=3.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from textblob) (3.5)
# Requirement already satisfied: regex in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nltk>=3.1->textblob) (2021.3.17)
# Requirement already satisfied: joblib in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nltk>=3.1->textblob) (1.0.1)
# Requirement already satisfied: click in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nltk>=3.1->textblob) (7.1.2)
# Requirement already satisfied: tqdm in /srv/conda/envs/notebook/lib/python3.7/site-packages (from nltk>=3.1->textblob) (4.59.0)
# Requirement already satisfied: tweepy in /srv/conda/envs/notebook/lib/python3.7/site-packages (3.10.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tweepy) (1.15.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from tweepy) (2.25.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (1.26.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Enter Keyword/Tag to search about:  modi
# Enter how many tweets to search:  100
# RT @EnergyMamata: @BJP4Bengal Why did you attached this chor Modi’s pic with every candidate?
# People think about the fuel prices after see…
# RT @ssingapuri: *👏Joseph Hope, Editor-in-Chief of the New York Times:*
# Narendra Modi's sole aim is to make India a better Country.. If he i…
# @BJP4Bengal Why did you attached this chor Modi’s pic with every candidate?
# People think about the fuel prices aft… https://t.co/LY7lILVImb
# RT @Reeema_kaur: PM Modi blasting out TMC and Congress in West Bengal.....
#
# Vote for Sonar Bangal..... A
# @narendramodi https://t.co/ae8yANw…
# RT @ukshahi: The Modi Govt is building 57 new border roads under 2 phases of India China Border Roads(ICBR) Project, 32 helipads, 47 ITBP B…
# RT @Bharatiyasatyam: Friendship Goals❤️
# Mota Bhai - Modi Ji❤️
# #India_With_PM_Modi https://t.co/0dOHZofgyx
# RT @Kisanektamorcha: More than 300 Farmers Sacrificed their Lives during the Protest &amp; still no affect on the Modi Government!!
#
# Wake Up Ca…
# RT @Kisanektamorcha: More than 300 Farmers Sacrificed their Lives during the Protest &amp; still no affect on the Modi Government!!
#
# Wake Up Ca…
# Has this been ever thought of ? 🤨
# Or, is there something more sinister,  to the thought itself ? 🤔… https://t.co/yolM28uUSY
# RT @Aakar__Patel: He was Modi government’s chief economic advisor from 2014 to 2018. His research says GDP growth was overestimated by 2% (…
# RT @SaketGokhale: On 27 March (1st day of polling in Bengal), Modi will visit Orakandi in Bangladesh where the birthplace of Harichand Thak…
# RT @WilfredQuadros: Modi's condition when his minions are busy spewing venom.. https://t.co/oSO230hxmJ
# RT @ARanganathan72: From Didi to Sadhvi, it won’t be long before Mamata Banerjee begins her rally speeches with chants of ‘Joy Shri Ram’. A…
# @kushal_mehra @shambhav15 When congress was in power..
# Its all RSS &amp; fascist Modi's fault..
# RT @AdamBKushner: The anecdotes in this @kapskom piece are astounding: Students brought to school on Sunday to hail Modi's birthday, his na…
# RT @rose_k01: AMAZING 👏👏 This Man is ONE MAN ARMY.. PROUD of the way he took on Dakait &amp; his supporters &amp; STUNNED them with his FEARLESS "N…
# Picture Perfect....all looters ate made to work hard🤣
#
# Our #Modi jinis enjoying the tea in the mean time. Jai Hind https://t.co/Qn48XWV54q
# @AB54821623 @SitaramYechury What about mudra loans which was the flagship programme of Modi govt, made possible onl… https://t.co/jls1vOjxn6
# PM Modi attacks Congress, says its policies damaged state socially, culturally, politically https://t.co/tkccVhWlBd
# RT @sonaliranade: The Wholesale Offloading of Government Assets Will Be a Political Hot Potato for PM Modi https://t.co/n8BOFq61l5
#
# Where…
# RT @kdastgirkhan: It is official:
# 1. Pakistan has acquiesced to India's Kashmir annexation
# 2. Pakistan is appeasing India
#
# What happened to…
# RT @R1Ruhi: As Proved 60% of Modi ji's Twitter followers are fake.
#
# If the election is done by ballot paper, then 80% of Modi ji's voters w…
# RT @ani_digital: Andre Russell thanks PM Modi for sending COVID-19 vaccines to Jamaica
#
# Read @ANI Story |
# https://t.co/GY0yMkouVH https:…
# RT @ukshahi: The Modi Govt is building 57 new border roads under 2 phases of India China Border Roads(ICBR) Project, 32 helipads, 47 ITBP B…
# RT @theskindoctor13: @AndColorPockeT Maybe Modi ji told Amit Shah : Mere naam wale stadium me series harwaoge kya?
#
# Next, Amit Shah called…
# RT @KrisNair1: #Modi is fooling the People because he believe People are fools
# RT @ShekharGupta: Parliament raising FDI limit in pvt insurance companies to 74% is an important reform. It’s also a logical next step in w…
# RT @AdamBKushner: The anecdotes in this @kapskom piece are astounding: Students brought to school on Sunday to hail Modi's birthday, his na…
# RT @amaanbali: And they thought that govt is coming for just Agriculture &amp; Banks. Aag lagi hai toh ghar sab k jalenge sahab. Can’t wait for…
# RT @kumarakshay1: @mondalsudipto PBM gushed over Modi before he became PM, and early years
#
# PBM cried over Modi after seeing him in action…
# RT @AdityaRajKaul: Jamaica and WI Cricketer Andre Russell thanking PM Narendra Modi and Indian High Commission for the gift of Made in Indi…
# RT @nsitharamanoffc: Poor are supporting Prime Minister Modi. They are happy because every programme of the government is reaching them: Sm…
# @pnvijay Yet.... keep voting modi ji for all misadventures
# @LibtardsKaDoc @Neh_hope_faith @ReallySwara @priyankagandhi Buddy I don't give a shit about nehru..... But I wish t… https://t.co/S3iTpqLwor
# On the same count, if RSS is compared to Blackhole, one day it will gulp Modi star ⭐️ https://t.co/pG2izSXi51
# RT @paki332: The army apologized to Nawaz Sharif, Pervez Rashid, Maryam Nawaz, Sir Almeida and every other person, political activist, for…
# RT @AdamBKushner: The anecdotes in this @kapskom piece are astounding: Students brought to school on Sunday to hail Modi's birthday, his na…
# RT @AdityaRajKaul: Jamaica and WI Cricketer Andre Russell thanking PM Narendra Modi and Indian High Commission for the gift of Made in Indi…
# RT @rishibagree: BJP govt is spending Rs 38000 crores for Char Dham infrastructure whereas the total wealth in all the temples there is not…
# @kstweets_ @kittyvaasal You vote didn't get BJP elected.
#
# Where BJP won with enough of people's votes, people are… https://t.co/emj9X9m4DI
# RT @HasibaAmin: Took 60 years to build, sold in 7 years. Modi hai to pumpkin hai. https://t.co/fjbIaDbReO
# RT @amaanbali: And they thought that govt is coming for just Agriculture &amp; Banks. Aag lagi hai toh ghar sab k jalenge sahab. Can’t wait for…
# RT @abhijeet_dipke: Mamata Banerjee writes to Arvind Kejriwal :
#
# "Modi and Shah have not been able to stomach the humiliating defeat BJP su…
# RT @MajorPoonia: This Modi wave will topple Mamta Didi’s Govt for sure !
# #Purulia https://t.co/b2NlpcrP8w
# RT @Kodungolan737: Outrageous!
#
# Modi is reported to be in contact with Pak Govt before May 2014 elections and influenced nixing of a deal t…
# RT @fekubawa: Empowering Lt. Governor in Delhi is continuing efforts of Modi govt to kill federalism in India just like GST.
# beware this w…
# @harip_rk @ANI News: Any news related to ayodhya.
# Muslim logic: This is Modi plan for elections.
#
# News: Increase i… https://t.co/GB0qtsgmmv
# RT @AlexTaylorNews: So, it seems, according to @BBCr4today that next month's vaccine shortage in the UK is mainly because India has suddenl…
# RT @Hajindersingh2: Hey Sanghi lala , unlike your ideological ancestors or current leader #Modi , Nehru never made any misogynist or sexist…
# RT @MajorPoonia: This Modi wave will topple Mamta Didi’s Govt for sure !
# #Purulia https://t.co/b2NlpcrP8w
# This is rhetorical Ravi anna. He HAS lost sanity. He thinks he can win TN by spreading lies against Modi. How much… https://t.co/498XsdTBHb
# RT @khushibanwait: #300DeathsAtProtest
# #300DeathsAtProtest
# FARMERS DYING
# MODI ENJOYING
# WAH MODI JI WAH https://t.co/SBJwCVSZBJ
# RT @SurrbhiM: The people who called themselves as 'neutral' are the most silent supporters of Modi . Time has come to choose your sides , w…
# RT @pragyakaushika: I will support Suvendu, will go to PM Modi's rally if asked: TMC MP Sisir Adhikari. @ANI https://t.co/n0RVJfsjbi
# RT @RLD4ScSt: Rs 50,000 crore, or 20% of funds allotted for SC welfare, left unused by Modi govt in 4 years.
#
# #ModiFail
#
# https://t.co/iMcX…
# RT @rose_k01: AMAZING 👏👏 This Man is ONE MAN ARMY.. PROUD of the way he took on Dakait &amp; his supporters &amp; STUNNED them with his FEARLESS "N…
# The Death Sentence will always stay at the cornerstone of democratic action so child molesting sex offenders such a… https://t.co/guwE4bHLjs
# RT @Kamran_Yousaf: Yesterday's speech by @ImranKhanPTI &amp; today's speech by Army Chief at #IslamabadDialogue clearly reflect a shift in Paki…
# RT @ARanganathan72: This old trope of 'Modi is Communal' doesn't work anymore. Because facts prove otherwise.
#
# My views on @TimesNow with @…
# With the release of the list of candidates, the way BJP leaders and activists have become so chaotic, tearing up Mo… https://t.co/Me0M8JNJGX
# RT @AvishekPL: West Bengal BJP welcomes our honorable Prime Minister Shri Narendra Modi on the 18th of March. We thank him for his commitme…
# RT @AvishekPL: It’s tragic that in a state-led by a woman, the condition of women is deteriorating by the day. WB BJP welcomes Shri Narendr…
# RT @SurajKrBauddh: When Modi was scraping the democracy in J&amp;K, Delhi was silently smiling. Now it's Delhi turn. Enjoy dear!
# RT @AvishekPL: TMC govt has miserably failed at creating a nurturing environment for industries. WB BJP welcomes Shri Narendra Modi on 18 M…
# RT @AvishekPL: No jobs, no prospects, and a callous regime. This is the grim reality of Bengal’s youth. We welcome Shri Narendra Modi on 18…
# RT @theskindoctor13: @AndColorPockeT Maybe Modi ji told Amit Shah : Mere naam wale stadium me series harwaoge kya?
#
# Next, Amit Shah called…
# RT @Vignesh_TMV: More than 300 farmers have lost their lives during the #FarmersProtest in Delhi.
#
# PM Modi hasn't said a word about the li…
# RT @AvishekPL: West Bengal has arguably become the Scam Capital of the country. WB BJP welcomes Shri Narendra Modi on 18 March and we thank…
# @TimesNow Chai wale ko thama diyya india ko sambalne ke liyya. Aur kya umeed kar sakthe hein. INDIANS  are educated… https://t.co/ANmCWh6J8w
# @LubnaaSabir1 No significant movement started from Srinagar  but Poonch Dhirkot Muzaffarabad, Skardu later on assis… https://t.co/7JLg2DzQbU
# RT @amaanbali: And they thought that govt is coming for just Agriculture &amp; Banks. Aag lagi hai toh ghar sab k jalenge sahab. Can’t wait for…
# RT @hariharanCP2: Inter-Parliamentary Union head Duarte Pacheco hails PM Modi’s work during pandemic
# https://t.co/SGpRZGcu91
#
# via NaMo App…
# RT @Anees_Speaks: Do you know?
#
# It's @KChiruTweets who launched "Clean India" Campaign on 24th July,2013 when he was the Tourism Minister.…
# Cooperation must for ensuring resilience of global systems: PM Modi
# https://t.co/ri7ZrbeKmU
#
# via NaMo App https://t.co/7Cb9ZJFRzy
# @yazhini_pm She was modi twitter handler..it wing
# RT @DuniyaSidNaazKi: Sid clicked that AgMi wala picture to post the story then Kaushal &amp; Mehul snatched his phone from his hand to post the…
# RT @sidhant: Formidable Fortnight..
# 19th to 21st: US Defence Secretary In India
#
# 22nd: Afghan FM on India visit
#
# 22nd-23rd: UNHRC vote on S…
# RT @rose_k01: AMAZING 👏👏 This Man is ONE MAN ARMY.. PROUD of the way he took on Dakait &amp; his supporters &amp; STUNNED them with his FEARLESS "N…
# RT @Diedmocratic: Sex is great but have you ever consider slapping modi
# RT @MajorPoonia: This Modi wave will topple Mamta Didi’s Govt for sure !
# #Purulia https://t.co/b2NlpcrP8w
# Hey Sanghi lala , unlike your ideological ancestors or current leader #Modi , Nehru never made any misogynist or se… https://t.co/lJpqNir5T6
# RT @BhadraPunchline: "Pakistani cabinet was on verge of formally approving pact when I can reveal that it was spiked by Modi, who through U…
# RT @Kodungolan737: Outrageous!
#
# Modi is reported to be in contact with Pak Govt before May 2014 elections and influenced nixing of a deal t…
# RT @pbhushan1: Ganesh Joshi, BJP's Uttarakhand minister who became famous for beating up the horse Shaktiman, says women should stay home &amp;…
# RT @knowthenation: Did this incident with PM Modi happen before or after you faked an entire interview of George Fernandes and were sacked…
# Mr.Narendra Modi PM: Treat all Ministers and Bureaucrats in  Government Hospitals in India Only - Sign the Petition… https://t.co/voIiv6mgtU
# RT @LoyalSachinFan: Now whole world is getting taste of Mumbai Indians DNA. https://t.co/yvgjSnUIhd
# RT @GorwayGlobal: His defence of Demonetisation was the most bizarre I've heard yet. If it was such a disaster, as people claimed, how come…
# RT @Cryptic_Miind: Breaking: OLX to make Modi and Nirmala Sitharaman their brand ambassadors.
# RT @kdastgirkhan: It is official:
# 1. Pakistan has acquiesced to India's Kashmir annexation
# 2. Pakistan is appeasing India
#
# What happened to…
# RT @kookykarthik: Ashoka's long list of corporate founders and trustees, from Pramath Sinha to Vineet Gupta, all of whom want to do busines…
# RT @Yadavji_: Proud Moment for our country 🔥
#
# Jamaica and West Indies Cricketer
# "Andre Russell" thanking PM Narendra Modi and Indian High C…
# RT @ndtv: "Narendra Modi promised to vaccinate people of Bihar after coming to power. But did they provide vaccines? No, they did not. They…
# RT @Cryptic_Miind: Actor Arun Govil who played Bhagwan Ram in Ramayan, has joined BJP.
#
# Bhakts can now claim that Modi has brought promised…
# RT @GorwayGlobal: @NalinSKohli beat the drum for JAM - janDhan, aadhaar and Mobile, with which the #Modi Govt, he claimed, helped 420 milli…
# RT @Aakar__Patel: He was Modi government’s chief economic advisor from 2014 to 2018. His research says GDP growth was overestimated by 2% (…
# RT @iKuchayHilal: Everything aside, the deteriorating condition of india under Modi regime is so satisfying.
# RT @pragyakaushika: I will support Suvendu, will go to PM Modi's rally if asked: TMC MP Sisir Adhikari. @ANI https://t.co/n0RVJfsjbi
# RT @imMAK02: 300 Farmers died during Farmers protest but Modi govt don't even give a damn!
#
# Modi was CM when 2000 Muslims were killed in G…
# RT @TabbuRao: It is 2 months since #Covid-19 vaccinations began and less than 4 crore people are covered. This is a reflection of the poor…
# How people are reacting on modi by analyzing 100 tweets.
#
# General Report:
# Weakly Positive
#
# Detailed Report:
# 11.00% people thought it was positive
# 22.00% people thought it was weakly positive
# 10.00% people thought it was strongly positive
# 2.00% people thought it was negative
# 9.00% people thought it was weakly negative
# 1.00% people thought it was strongly negative
# 43.00% people thought it was neutral
